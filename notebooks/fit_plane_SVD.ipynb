# %% [markdown]
# # Fit Plane with SVD
#
# Problem with simple three point fit: we may have more points to which we can/ want to fit a plane - which would also mean more information (and probably an estimate of uncertainty)!
#
# _How can we do that?_
#
# ## Singular Value Decomposition
#
# Better option: minimize *orthogonal* distance between all points and the plane! Turns out, this problem can be solved quite easily using SVD!
#
# Here an implementation (from: http://stackoverflow.com/questions/12299540/plane-fitting-to-4-or-more-xyz-points):
#
# This method is again implemented in the module `struct_geo.py` in the function `plane_fit()`:

# %%
import os, sys
sys.path.append(r"..")
import importlib
import numpy as np
import mplstereonet
# %matplotlib inline

# %%
from googlepicks import kml_to_plane
importlib.reload(kml_to_plane)
# Out:
# <module 'googlepicks.kml_to_plane' from '..\\googlepicks\\kml_to_plane.py'>

# %% [markdown]
# ## Fit plane to three points
#
# </p>
#
# <div class="alert alert-success">
#   <strong>Your task:</strong> Fill in your point positions in the next cell:
# </div>

# %%
# Replace x,y,z with the actual data:
# p_0 = (x, y, z)
# p_1 = (x, y, z)
# p_2 = (x, y, z)
p_0, p_1, p_2 = (1,0,0), (0,0,0), (0,1,1)

# %% [markdown]
# The next cell can then be executed to obtain the dip-direction and dip values:

# %%
points = [p_0, p_1, p_2]
ps = kml_to_plane.PointSet(type='nongeo', zone=0)
for p in points:
    ps.add_point(kml_to_plane.Point(x = p[0], y = p[1], z = p[2], type = 'nongeo', zone=0))

ps.get_orientation()
print("(%03d/%02d)" % (np.round(ps.dip_direction), np.round(ps.dip)))
# Out:
# (180/45)

# %% [markdown]
# ## Create a stereonet plot
#
# And because we are used to visualse data for a better interpretation, here a stereonet plot:

# %%
ps.stereonet()
